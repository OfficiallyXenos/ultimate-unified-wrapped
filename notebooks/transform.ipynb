# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users'

# %%
spotify_df = pd.read_parquet((r"C:\Users\PC\Desktop\ultimate-unified-wrapped\data\processed\spotify_cleaned.parquet"))

# %%
spotify_df.head()
# Out:
#                   timestamp platform  duration_ms conn_country  \
# 0 2025-01-01 05:54:20+00:00  android       147169           NG
# 1 2025-01-01 05:56:38+00:00  android       147169           NG
# 2 2025-01-01 05:58:56+00:00  android       147169           NG
# 3 2025-01-01 06:01:14+00:00  android       147169           NG
# 4 2025-01-01 06:03:32+00:00  android       147169           NG
#
#            ip_addr   track_name artist_name   album_name  \
# 0  105.112.193.198  Let Me Know       L.A.X  Let Me Know
# 1  105.112.193.198  Let Me Know       L.A.X  Let Me Know
# 2  105.112.193.198  Let Me Know       L.A.X  Let Me Know
# 3  105.112.193.198  Let Me Know       L.A.X  Let Me Know
# 4  105.112.193.198  Let Me Know       L.A.X  Let Me Know
#
#                             spotify_uri episode_name  ...  \
# 0  spotify:track:16artMqVuD2b0ZGfgsHsOY         None  ...
# 1  spotify:track:16artMqVuD2b0ZGfgsHsOY         None  ...
# 2  spotify:track:16artMqVuD2b0ZGfgsHsOY         None  ...
# ...

# %%
spotify_df.columns
# Out:
# Index(['timestamp', 'platform', 'duration_ms', 'conn_country', 'ip_addr',
#        'track_name', 'artist_name', 'album_name', 'spotify_uri',
#        'episode_name', 'episode_show_name', 'spotify_episode_uri',
#        'audiobook_title', 'audiobook_uri', 'audiobook_chapter_uri',
#        'audiobook_chapter_title', 'reason_start', 'reason_end', 'shuffle',
#        'skipped', 'offline', 'offline_timestamp', 'incognito_mode'],
#       dtype='object')

# %%
youtube_df = pd.read_parquet(r"C:\Users\PC\Desktop\ultimate-unified-wrapped\data\processed\youtube_history_2025.parquet")
youtube_df.head()
# Out:
#          track_name  artist_name                        timestamp  \
# 0          everyday  Fireboy DML 2025-12-07 13:39:35.446000+00:00
# 1              yawa  Fireboy DML 2025-12-07 13:36:35.961000+00:00
# 2           need me  Fireboy DML 2025-12-07 13:34:03.274000+00:00
# 3         obaa sima  Fireboy DML 2025-12-07 13:30:57.922000+00:00
# 4  change your life  Fireboy DML 2025-12-07 13:27:40.184000+00:00
#
#                                         titleUrl
# 0  https://music.youtube.com/watch?v=6I5dsnlaypw
# 1  https://music.youtube.com/watch?v=8udliiZz2Kc
# 2  https://music.youtube.com/watch?v=DJPQnQ9FWwQ
# 3  https://music.youtube.com/watch?v=wn_TJ9svwHI
# 4  https://music.youtube.com/watch?v=tyM9bB2kNFM

# %%
print(spotify_df['track_name'].unique())
print(youtube_df['track_name'].unique())
# Out:
# ['Let Me Know' 'Good Feeling' 'All Night Long (All Night)' ...
#  'DEAD MAN WALKING' 'Murvlana' 'Beautiful People']
# ['everyday' 'yawa' 'need me' ...
#  'Show Dem Camp x The Cavemen. x Nsikak David - Johni (Official Visualiser)'
#  'All Eyes On Me' '50 CENT IN DA CLUB REMIX/PARODY! (IGBO VERSION)']

# %%
spotify_df['track_name'].dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 spotify_df['track_name'].dtype
#
# NameError: name 'spotify_df' is not defined

# %%
spotify_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 spotify_df.columns
#
# NameError: name 'spotify_df' is not defined
