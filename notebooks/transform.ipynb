# %%
import pandas as pd
import os

# %%
os.chdir("..")

spotify_path = os.path.join("data", "processed", "Spotify_history.parquet")
youtube_path = os.path.join("data", "processed", "youtube_history_2025.parquet")

spotify_df = pd.read_parquet(spotify_path)

# %%
spotify_df.head()
# Out:
#                      timestamp platform  duration_ms conn_country  \
# 4211 2025-01-01 05:54:20+00:00  android       147169           NG
# 4212 2025-01-01 05:56:38+00:00  android       147169           NG
# 4213 2025-01-01 05:58:56+00:00  android       147169           NG
# 4214 2025-01-01 06:01:14+00:00  android       147169           NG
# 4215 2025-01-01 06:03:32+00:00  android       147169           NG
#
#               ip_addr   track_name artist_name   album_name  \
# 4211  105.112.193.198  Let Me Know       L.A.X  Let Me Know
# 4212  105.112.193.198  Let Me Know       L.A.X  Let Me Know
# 4213  105.112.193.198  Let Me Know       L.A.X  Let Me Know
# 4214  105.112.193.198  Let Me Know       L.A.X  Let Me Know
# 4215  105.112.193.198  Let Me Know       L.A.X  Let Me Know
#
#                                spotify_uri episode_name  ... audiobook_uri  \
# 4211  spotify:track:16artMqVuD2b0ZGfgsHsOY         None  ...          None
# ...

# %%
print(os.getcwd())
print(os.path.exists(r"C:\Users\PC\Desktop\ultimate-unified-wrapped\data\processed\youtube_history_2025.parquet"))
# Out:
# c:\
# True

# %%
youtube_df = pd.read_parquet(r"C:\Users\PC\Desktop\ultimate-unified-wrapped\data\processed\youtube_history_2025.parquet")
youtube_df.head()
# Out:
#          track_name  artist_name                        timestamp  \
# 0          everyday  Fireboy DML 2025-12-07 13:39:35.446000+00:00
# 1              yawa  Fireboy DML 2025-12-07 13:36:35.961000+00:00
# 2           need me  Fireboy DML 2025-12-07 13:34:03.274000+00:00
# 3         obaa sima  Fireboy DML 2025-12-07 13:30:57.922000+00:00
# 4  change your life  Fireboy DML 2025-12-07 13:27:40.184000+00:00
#
#                                         titleUrl
# 0  https://music.youtube.com/watch?v=6I5dsnlaypw
# 1  https://music.youtube.com/watch?v=8udliiZz2Kc
# 2  https://music.youtube.com/watch?v=DJPQnQ9FWwQ
# 3  https://music.youtube.com/watch?v=wn_TJ9svwHI
# 4  https://music.youtube.com/watch?v=tyM9bB2kNFM

# %%
print(spotify_df['track_name'].unique())
print(youtube_df['track_name'].unique())
# Out:
# ['Let Me Know' 'Good Feeling' 'All Night Long (All Night)' ...
#  'DEAD MAN WALKING' 'Murvlana' 'Beautiful People']
# ['everyday' 'yawa' 'need me' ...
#  'Show Dem Camp x The Cavemen. x Nsikak David - Johni (Official Visualiser)'
#  'All Eyes On Me' '50 CENT IN DA CLUB REMIX/PARODY! (IGBO VERSION)']

# %%
youtube_df[youtube_df['artist_name'] == "Ayra Starr"]
# Out:
#                                  track_name artist_name  \
# 146                                Hot Body  Ayra Starr
# 285                          Who’s Dat Girl  Ayra Starr
# 500                               Gimme Dat  Ayra Starr
# 576                          Who’s Dat Girl  Ayra Starr
# 1205                         Who’s Dat Girl  Ayra Starr
# 1261                               Hot Body  Ayra Starr
# 1633                         Who’s Dat Girl  Ayra Starr
# 1657                         Who’s Dat Girl  Ayra Starr
# 1762                         Who’s Dat Girl  Ayra Starr
# 1907                         Who’s Dat Girl  Ayra Starr
# 1921                                   Away  Ayra Starr
# 1948                       Lagos Love Story  Ayra Starr
# 1987                      Goodbye (Warm Up)  Ayra Starr
# 2086                         Who’s Dat Girl  Ayra Starr
# 2120                         Who’s Dat Girl  Ayra Starr
# 2265                              Bad Vibes  Ayra Starr
# ...

# %%
spotify_df[spotify_df['artist_name'] == "Arya Star"]
# Out:
# Empty DataFrame
# Columns: [timestamp, platform, duration_ms, conn_country, ip_addr, track_name, artist_name, album_name, spotify_uri, episode_name, episode_show_name, spotify_episode_uri, audiobook_title, audiobook_uri, audiobook_chapter_uri, audiobook_chapter_title, reason_start, reason_end, shuffle, skipped, offline, offline_timestamp, incognito_mode]
# Index: []
#
# [0 rows x 23 columns]
