# %%
import pandas as pd

# %%
enriched_df = pd.read_parquet(r'C:\Users\PC\Desktop\ultimate-unified-wrapped\data\processed\enriched_music_history.parquet')

# %%
enriched_df.isna().sum()
# Out:
# timestamp                 0
# track                     0
# artist                    0
# duration_ms            4154
# skipped                4154
# source                    0
# date                      0
# month                     0
# month_name                0
# day_of_week               0
# hour                      0
# week_of_year              0
# spotify_id              284
# album_name              284
# album_release_date      284
# album_art_url           284
# popularity              284
# explicit                284
# duration_ms_spotify     284
# genres                    0
# dtype: int64

# %%
print(len(enriched_df))
# Out:
# 13607

# %%
enriched_df['explicit'].unique()
# Out:
# array([False, True, None], dtype=object)

# %%
missing_data = enriched_df[enriched_df['explicit'].isna()]
missing_data.head()
# Out:
#                             timestamp  \
# 1333 2025-01-29 15:23:53.887000+00:00
# 1340 2025-01-29 15:44:12.058000+00:00
# 1341 2025-01-29 15:47:23.660000+00:00
# 1342 2025-01-29 15:50:15.372000+00:00
# 1343 2025-01-29 15:50:57.886000+00:00
#
#                                                   track         artist  \
# 1333    50 cent in da club remix/parody! (igbo version)  bigdesodogwu
# 1340  show dem camp x the cavemen. x nsikak david ft...  show dem camp
# 1341  show dem camp x the cavemen. x nsikak david - ...  show dem camp
# 1342  show dem camp x the cavemen. x nsikak david - ...  show dem camp
# 1343  show dem camp x the cavemen. x nsikak david - ...  show dem camp
#
#       duration_ms skipped         source        date  month month_name  \
# 1333          NaN    None  youtube music  2025-01-29      1    January
# 1340          NaN    None  youtube music  2025-01-29      1    January
# 1341          NaN    None  youtube music  2025-01-29      1    January
# ...

# %%
missing_data['track'].unique()
# Out:
# array(['50 cent in da club remix/parody! (igbo version)',
#        'show dem camp x the cavemen. x nsikak david ft. ruti - train (official visualiser)',
#        'show dem camp x the cavemen. x nsikak david - sudden day (official visualiser)',
#        'show dem camp x the cavemen. x nsikak david - johni (official visualiser)',
#        'show dem camp x the cavemen. x nsikak david - fall (official visualiser)',
#        'show dem camp x the cavemen. x nsikak david ft. tim lyre - buga (official visualiser)',
#        'show dem camp x the cavemen. x nsikak david ft. obongjayar - omftr (official visualiser)',
#        'show dem camp x the cavemen. x nsikak david - no love in lagos (official visualiser)',
#        'buju - italy (refix) ft blaq diamond', 'lahoo',
#        'basketmouth, @bnxntye - your body',
#        'rema - time n affection feat. chris brown',
#        'niniola - all eyes on me', 'niniola ft femi kuti - fantasy',
# ...

# %%
missing_data['source'].unique()
# Out:
# array(['youtube music'], dtype=object)
